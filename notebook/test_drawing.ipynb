# %% [markdown]
# # Test Molecule Drawing Functions

# %%
# Autoreload modules
# %load_ext autoreload
# %autoreload 2

# Add local path
import sys
sys.path.append("/Users/Jphild/Documents/Papers/_***Thesis/MRP7Pred/")

import pandas as pd
import numpy as np

from pandas import DataFrame
from numpy import ndarray
from typing import Union, Any, Dict, Tuple, List

from utils import standardize_smiles, draw_molecule
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/Jphild/anaconda3/envs/mrp7pred/lib/python3.7/site-packages/tqdm/std.py:703: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
# a random molecule
smiles_rand = "CCNCC"

# vinblastine
smiles_vbl = "CCC1(CC2CC(C3=C(CCN(C2)C1)C4=CC=CC=C4N3)(C5=C(C=C6C(=C5)C78CCN9C7C(C=CC9)(C(C(C8N6C)(C(=O)OC)O)OC(=O)C)CC)OC)C(=O)OC)O"
# Out:
# /Users/Jphild/anaconda3/envs/mrp7pred/lib/python3.7/site-packages/tqdm/std.py:703: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
std_vbl = standardize_smiles(smiles_vbl)

# %%
std_vbl
# Out:
# 'CCC1(O)CC2CN(CCc3c([nH]c4ccccc34)C(C(=O)OC)(c3cc4c(cc3OC)N(C)C3C(O)(C(=O)OC)C(OC(C)=O)C5(CC)C=CCN6CCC43C65)C2)C1'

# %%
draw_molecule(std_vbl)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300 at 0x14962BC50>

# %%
draw_molecule(std_vbl, highlight="CO", subImgSize=(500,500))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x500 at 0x14909E810>

# %%
draw_molecule(std_vbl, highlight="C(=O)O", subImgSize=(500,500))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x500 at 0x1490AC3D0>

# %%
draw_molecule("c1cc(C(=O)O)c(OC(=O)C)cc1", highlight="C(=O)O", subImgSize=(500,500))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x500 at 0x1490A6FD0>
