# %% [markdown]
# # Process NCI compound data

# %%
import pandas as pd
import re
import numpy as np
NSC_REF_DIR = "../data/cancer_cell/nci_nsc_name.tab"
DATA_DIR = "../data/cancer_cell/mmc7.csv"

# Autoreload modules
# %load_ext autoreload
# %autoreload 2

# Add local path
import sys
sys.path.append("/Users/Jphild/Documents/Papers/_***Thesis/MRP7Pred/")

from mrp7pred.utils import standardize_smiles

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### 1. Load NSC reference data

# %%
df_ref = pd.read_csv(NSC_REF_DIR, sep="\t")

# %%
df_ref.head()
# Out:
#    E_NSC                                             E_NAME  \
# 0    186  8-hydroxy-3,4,5-trimethyl-6-oxo-4,6-dihydro-3H...
# 1    740  N-(4-(((2,4-diamino-6-pteridinyl)methyl)(methy...
# 2    742           O-(1lambda~5~-diazenylideneacetyl)serine
# 3    750      4-((methylsulfonyl)oxy)butyl methanesulfonate
# 4    752                 2-amino-9H-purin-6-yl hydrosulfide
#
#                                         E_NAMESET(0)  \
# 0  8-hydroxy-3,4,5-trimethyl-6-oxo-4,6-dihydro-3H...
# 1  N-(4-(((2,4-diamino-6-pteridinyl)methyl)(methy...
# 2  O-(1lambda~5~-diazenylideneacetyl)serine (ACD/...
# 3  4-((methylsulfonyl)oxy)butyl methanesulfonate ...
# 4      2-amino-9H-purin-6-yl hydrosulfide (ACD/Name)
#
#                                         E_NAMESET(1)  \
# 0  3H-2-Benzopyran-7-carboxylic acid, 4,6-dihydro...
# 1                                       Amethopterin
# 2                             o-Diazoacetyl-L-serine
# 3                                           AN 33501
# 4               2-amino-9H-purine-6-thiol (ACD/Name)
#
#                              E_NAMESET(2)          E_NAMESET(3)  \
# 0                               Antimycin              Citriain
# 1                                CL 14377            EMT 25,299
# 2  Acetic acid, diazo-, ester with serine              Azaserin
# 3                                Busulfan             Busulphan
# 4                                 BW 5071  Guanine, thio- (VAN)
#
#                                         E_NAMESET(4) E_NAMESET(5)  \
# 0                                           Citrinin          NaN
# 1  Glutamic acid, {N-[p-[[(2,} 4-diamino-6-pterid...        HDMTX
# 2                                    Azaserine(USAN)    AZASERINE
# 3                                           Buzulfan    C.B. 2041
# 4                                             Lanvis      NSC 752
#
#                                         E_NAMESET(6)  \
# 0                                                NaN
# 1  L-Glutamic acid, {N-[4-[[2,} 4-diamino-6-pteri...
# 2                                                AZS
# 3                                         Citosulfan
# 4                      Purine-6(1H)-thione, 2-amino-
#
#                E_NAMESET(7)  ... E_NAMESET(60) E_NAMESET(61) E_NAMESET(62)  \
# 0                       NaN  ...           NaN           NaN           NaN
# 1                Metatrexan  ...           NaN           NaN           NaN
# 2                  C.I. 337  ...           NaN           NaN           NaN
# 3                   CB 2041  ...           NaN           NaN           NaN
# 4  Purine-6-thiol, 2-amino-  ...           NaN           NaN           NaN
#
#   E_NAMESET(63) E_NAMESET(64) E_NAMESET(65) E_NAMESET(66) E_NAMESET(67)  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#       E_CAS                                           E_SMILES
# 0  518-75-2      CC2=C1[C@H]([C@H](OC=C1C(=C(C(=O)O)C2=O)O)C)C
# 1   59-05-2  NC1=C2C(=NC(=N1)N)N=CC(=N2)CN(C)C3=CC=C(C(N[C@...
# 2  115-02-6                 C([C@H](COC(=O)C=[N+]=[N-])N)(=O)O
# 3   55-98-1                     C[S](=O)(=O)OCCCCO[S](C)(=O)=O
# 4  154-42-7                         SC1=C2C(=NC(=N1)N)[NH]C=N2
#
# [5 rows x 72 columns]

# %%
df_ref.shape
# Out:
# (1413, 72)

# %%
df_ref.loc[0, "E_NAMESET(67)"] is np.nan
# Out:
# True

# %%
# Find the simplest names
df_ref["NAME_SIMPLE"] = np.nan
for index in range(len(df_ref)):
    name_l = [v for v in df_ref.loc[index, "E_NAMESET(0)":"E_NAMESET(67)"] if (v is not np.nan and v != "???")]
    if len(name_l) < 1: # no name
        simplest_name == f"NSC{df_ref.loc[index, 'E_NSC']}"
    else:
        simplest_name = sorted(name_l, key=len)[0]
    df_ref.loc[index, "NAME_SIMPLE"] = simplest_name
    
df_ref[["E_NSC", "NAME_SIMPLE"]]
# Out:
#        E_NSC                                        NAME_SIMPLE
# 0        186                                           Citriain
# 1        740                                                MTX
# 2        742                                                AZS
# 3        750                                              GT 41
# 4        752                                                 TG
# ...      ...                                                ...
# 1408  698691  N-ethyl-5-(2-(2-(5-(ethylamino)-1,3,4-thiadiaz...
# 1409  698790  26-(hexopyranosyloxy)-22-methoxyfurost-5-en-3-...
# 1410  698792  3-((2-O-(6-deoxyhexopyranosyl)-3-O-hexopyranos...
# 1411  699477  3-((2-O-(6-deoxyhexopyranosyl)-3-O-hexopyranos...
# 1412  699479  3-((2-O-(6-deoxyhexopyranosyl)-3-O-hexopyranos...
#
# [1413 rows x 2 columns]

# %%
df_ref = df_ref.rename(columns={
    "E_NSC" : "nsc_id",
    "E_SMILES" : "smiles",
    "E_CAS" : "cas",
    "NAME_SIMPLE" : "name"
})
df_ref.head()
# Out:
#    nsc_id                                             E_NAME  \
# 0     186  8-hydroxy-3,4,5-trimethyl-6-oxo-4,6-dihydro-3H...
# 1     740  N-(4-(((2,4-diamino-6-pteridinyl)methyl)(methy...
# 2     742           O-(1lambda~5~-diazenylideneacetyl)serine
# 3     750      4-((methylsulfonyl)oxy)butyl methanesulfonate
# 4     752                 2-amino-9H-purin-6-yl hydrosulfide
#
#                                         E_NAMESET(0)  \
# 0  8-hydroxy-3,4,5-trimethyl-6-oxo-4,6-dihydro-3H...
# 1  N-(4-(((2,4-diamino-6-pteridinyl)methyl)(methy...
# 2  O-(1lambda~5~-diazenylideneacetyl)serine (ACD/...
# 3  4-((methylsulfonyl)oxy)butyl methanesulfonate ...
# 4      2-amino-9H-purin-6-yl hydrosulfide (ACD/Name)
#
#                                         E_NAMESET(1)  \
# 0  3H-2-Benzopyran-7-carboxylic acid, 4,6-dihydro...
# 1                                       Amethopterin
# 2                             o-Diazoacetyl-L-serine
# 3                                           AN 33501
# 4               2-amino-9H-purine-6-thiol (ACD/Name)
#
#                              E_NAMESET(2)          E_NAMESET(3)  \
# 0                               Antimycin              Citriain
# 1                                CL 14377            EMT 25,299
# 2  Acetic acid, diazo-, ester with serine              Azaserin
# 3                                Busulfan             Busulphan
# 4                                 BW 5071  Guanine, thio- (VAN)
#
#                                         E_NAMESET(4) E_NAMESET(5)  \
# 0                                           Citrinin          NaN
# 1  Glutamic acid, {N-[p-[[(2,} 4-diamino-6-pterid...        HDMTX
# 2                                    Azaserine(USAN)    AZASERINE
# 3                                           Buzulfan    C.B. 2041
# 4                                             Lanvis      NSC 752
#
#                                         E_NAMESET(6)  \
# 0                                                NaN
# 1  L-Glutamic acid, {N-[4-[[2,} 4-diamino-6-pteri...
# 2                                                AZS
# 3                                         Citosulfan
# 4                      Purine-6(1H)-thione, 2-amino-
#
#                E_NAMESET(7)  ... E_NAMESET(61) E_NAMESET(62) E_NAMESET(63)  \
# 0                       NaN  ...           NaN           NaN           NaN
# 1                Metatrexan  ...           NaN           NaN           NaN
# 2                  C.I. 337  ...           NaN           NaN           NaN
# 3                   CB 2041  ...           NaN           NaN           NaN
# 4  Purine-6-thiol, 2-amino-  ...           NaN           NaN           NaN
#
#   E_NAMESET(64) E_NAMESET(65) E_NAMESET(66) E_NAMESET(67)       cas  \
# 0           NaN           NaN           NaN           NaN  518-75-2
# 1           NaN           NaN           NaN           NaN   59-05-2
# 2           NaN           NaN           NaN           NaN  115-02-6
# 3           NaN           NaN           NaN           NaN   55-98-1
# 4           NaN           NaN           NaN           NaN  154-42-7
#
#                                               smiles      name
# 0      CC2=C1[C@H]([C@H](OC=C1C(=C(C(=O)O)C2=O)O)C)C  Citriain
# 1  NC1=C2C(=NC(=N1)N)N=CC(=N2)CN(C)C3=CC=C(C(N[C@...       MTX
# 2                 C([C@H](COC(=O)C=[N+]=[N-])N)(=O)O       AZS
# 3                     C[S](=O)(=O)OCCCCO[S](C)(=O)=O     GT 41
# 4                         SC1=C2C(=NC(=N1)N)[NH]C=N2        TG
#
# [5 rows x 73 columns]

# %% [markdown]
# #### 2. Load Cancer Cell paper data
#
# This data includes the Pearson correlation coefficients for **gene mRNA expression (dCP)** and **drug sensitivity (dlogGI50)**
#
# Positive means more ABC transporter expression, more sensitive the tested cells become to the compound.
#
# Negative means more ABC transporter expression, less sensitive the cells be, which indicates potential substrates.

# %%
df = pd.read_csv(DATA_DIR)

# %%
df.head()
# Out:
#   NSC No.  ABC-G8  ABC-G5  ABC-G4  ABC-G2  ABC-G1  ABC-F3  ABC-F2  ABC-F1  \
# 0    2013    0.04    0.16    0.00   -0.01   -0.14    0.06    0.11   -0.22
# 1    3053   -0.05    0.04    0.20    0.22    0.24   -0.21   -0.28   -0.19
# 2    3970   -0.07   -0.03   -0.04    0.16   -0.24   -0.10   -0.23   -0.15
# 3    5890   -0.01    0.21   -0.04    0.21   -0.28    0.24   -0.03   -0.11
# 4    8120    0.14    0.02    0.05   -0.10    0.15   -0.02    0.10    0.08
#
#    ABC-E1  ...  ABC-A10  ABC-A9  ABC-A8  ABC-A7  ABC-A6  ABC-A5  ABC-A4  \
# 0   -0.05  ...    -0.08   -0.04   -0.03    0.04   -0.12   -0.02   -0.17
# 1   -0.34  ...    -0.17    0.07    0.28   -0.12    0.00   -0.10    0.14
# 2   -0.39  ...    -0.35    0.14    0.06    0.09    0.07   -0.07   -0.08
# 3   -0.21  ...    -0.35    0.14   -0.09    0.10    0.01    0.00    0.02
# 4    0.14  ...     0.09   -0.15   -0.12   -0.05   -0.21    0.07    0.07
#
#    ABC-A3  ABC-A2  ABC-A1
# 0    0.20    0.02    0.05
# 1   -0.11   -0.13   -0.27
# 2    0.03   -0.08   -0.29
# 3    0.27    0.19   -0.13
# 4   -0.18   -0.06    0.00
#
# [5 rows x 49 columns]

# %%
df.shape
# Out:
# (1429, 49)

# %%
df_c10 = df[["NSC No.", "ABC-C10"]]
df_c10 = df_c10.rename(columns={"NSC No." : "nsc_id", "ABC-C10" : "abcc10"})
df_c10["nsc_id"] = df_c10["nsc_id"].apply(lambda x: ''.join(re.findall(r"\((\d+)\)", x)) if not x.isnumeric() else x)

# %%
df_c10.head()
# Out:
#   nsc_id  abcc10
# 0   2013   -0.21
# 1   3053   -0.18
# 2   3970   -0.05
# 3   5890    0.01
# 4   8120   -0.01

# %%
# Test if all nsc_id's are numeric
all(df_c10['nsc_id'].str.isnumeric())
# Out:
# True

# %% [markdown]
# #### 3. Map compound info (name, smiles) to nsc_id

# %%
df_join = df_ref\
    .set_index("nsc_id")\
    .join(
        df_c10.set_index("nsc_id")
    )[["name", "cas", "smiles", "abcc10"]]

# %%
df_join.head()
# Out:
#             name       cas                                             smiles  \
# nsc_id
# 186     Citriain  518-75-2      CC2=C1[C@H]([C@H](OC=C1C(=C(C(=O)O)C2=O)O)C)C
# 740          MTX   59-05-2  NC1=C2C(=NC(=N1)N)N=CC(=N2)CN(C)C3=CC=C(C(N[C@...
# 742          AZS  115-02-6                 C([C@H](COC(=O)C=[N+]=[N-])N)(=O)O
# 750        GT 41   55-98-1                     C[S](=O)(=O)OCCCCO[S](C)(=O)=O
# 752           TG  154-42-7                         SC1=C2C(=NC(=N1)N)[NH]C=N2
#
#         abcc10
# nsc_id
# 186        NaN
# 740        NaN
# 742        NaN
# 750        NaN
# 752        NaN

# %%
df_join = df_join.reset_index()
df_join.head()
# Out:
#    nsc_id      name       cas  \
# 0     186  Citriain  518-75-2
# 1     740       MTX   59-05-2
# 2     742       AZS  115-02-6
# 3     750     GT 41   55-98-1
# 4     752        TG  154-42-7
#
#                                               smiles  abcc10
# 0      CC2=C1[C@H]([C@H](OC=C1C(=C(C(=O)O)C2=O)O)C)C     NaN
# 1  NC1=C2C(=NC(=N1)N)N=CC(=N2)CN(C)C3=CC=C(C(N[C@...     NaN
# 2                 C([C@H](COC(=O)C=[N+]=[N-])N)(=O)O     NaN
# 3                     C[S](=O)(=O)OCCCCO[S](C)(=O)=O     NaN
# 4                         SC1=C2C(=NC(=N1)N)[NH]C=N2     NaN

# %%
d = df_c10.set_index("nsc_id").to_dict("index")
df_join["abcc10"] = df_join["nsc_id"].apply(lambda x: d[str(x)].get("abcc10"))

# %%
df_join.shape
# Out:
# (1413, 5)

# %%
df_join.head()
# Out:
#    nsc_id      name       cas  \
# 0     186  Citriain  518-75-2
# 1     740       MTX   59-05-2
# 2     742       AZS  115-02-6
# 3     750     GT 41   55-98-1
# 4     752        TG  154-42-7
#
#                                               smiles  abcc10
# 0      CC2=C1[C@H]([C@H](OC=C1C(=C(C(=O)O)C2=O)O)C)C   -0.23
# 1  NC1=C2C(=NC(=N1)N)N=CC(=N2)CN(C)C3=CC=C(C(N[C@...    0.12
# 2                 C([C@H](COC(=O)C=[N+]=[N-])N)(=O)O   -0.03
# 3                     C[S](=O)(=O)OCCCCO[S](C)(=O)=O    0.04
# 4                         SC1=C2C(=NC(=N1)N)[NH]C=N2    0.08

# %%
df_join.to_csv("../data/joined_abcc10_nsc.csv")

# %% [markdown]
# #### 4. Identify potential substrates/non-substrates

# %%
THRESHOLD = -0.20

df_join = pd.read_csv("../data/cancer_cell/joined_abcc10_nsc_nscid-name.csv", index_col=0)
df_join.head()
# Out:
#    nsc_id      name       cas  \
# 0     186  Citriain  518-75-2
# 1     740       MTX   59-05-2
# 2     742       AZS  115-02-6
# 3     750     GT 41   55-98-1
# 4     752        TG  154-42-7
#
#                                               smiles  abcc10 nsc_id_name
# 0      CC2=C1[C@H]([C@H](OC=C1C(=C(C(=O)O)C2=O)O)C)C   -0.23      NSC186
# 1  NC1=C2C(=NC(=N1)N)N=CC(=N2)CN(C)C3=CC=C(C(N[C@...    0.12      NSC740
# 2                 C([C@H](COC(=O)C=[N+]=[N-])N)(=O)O   -0.03      NSC742
# 3                     C[S](=O)(=O)OCCCCO[S](C)(=O)=O    0.04      NSC750
# 4                         SC1=C2C(=NC(=N1)N)[NH]C=N2    0.08      NSC752

# %%
df_substrate = df_join[df_join["abcc10"]<=THRESHOLD]
df_nonsubstrate = df_join[df_join["abcc10"]>THRESHOLD]

# %%
len(df_substrate), len(df_nonsubstrate)
# Out:
# (101, 1312)

# %% [markdown]
# Count the results:
#
# |Threshold|Substrate|Non-substrate|
# |---|---|---|
# |-0.20|103|1326|
# |-0.25|51|1362|
# |-0.30|19|1394|

# %% [markdown]
# #### 5. Check duplicates with previous dataset
#
# Use standardized smiles as keys

# %%
df_previous = pd.read_csv("../data/manual/merged.csv", index_col=0)
df_previous.head()
# Out:
#           name                                             smiles  label
# 0   paclitaxel  CC1=C2C(C(=O)C3(C(CC4C(C3C(C(C2(C)C)(CC1OC(=O)...      1
# 1  vincristine  CCC1(CC2CC(C3=C(CCN(C2)C1)C4=CC=CC=C4N3)(C5=C(...      1
# 2         LTC4  CCCCCC=CCC=CC=CC=CC(C(CCCC(=O)O)O)SCC(C(=O)NCC...      1
# 3       E217bG  CC12CCC3C(C1CCC2OC4C(C(C(C(O4)C(=O)O)O)O)O)CCC...      1
# 4  gemcitabine              C1=CN(C(=O)N=C1N)C2C(C(C(O2)CO)O)(F)F      1

# %%
df_nci = pd.read_csv("../data/cancer_cell/joined_abcc10_nsc_nscid-name.csv", index_col=0)
df_nci.head()
# Out:
#    nsc_id      name       cas  \
# 0     186  Citriain  518-75-2
# 1     740       MTX   59-05-2
# 2     742       AZS  115-02-6
# 3     750     GT 41   55-98-1
# 4     752        TG  154-42-7
#
#                                               smiles  abcc10 nsc_id_name
# 0      CC2=C1[C@H]([C@H](OC=C1C(=C(C(=O)O)C2=O)O)C)C   -0.23      NSC186
# 1  NC1=C2C(=NC(=N1)N)N=CC(=N2)CN(C)C3=CC=C(C(N[C@...    0.12      NSC740
# 2                 C([C@H](COC(=O)C=[N+]=[N-])N)(=O)O   -0.03      NSC742
# 3                     C[S](=O)(=O)OCCCCO[S](C)(=O)=O    0.04      NSC750
# 4                         SC1=C2C(=NC(=N1)N)[NH]C=N2    0.08      NSC752

# %%
df_nci = df_nci.drop("name", axis=1).rename(columns={"nsc_id_name" : "name"})
df_nci.head()
# Out:
#    nsc_id       cas                                             smiles  \
# 0     186  518-75-2      CC2=C1[C@H]([C@H](OC=C1C(=C(C(=O)O)C2=O)O)C)C
# 1     740   59-05-2  NC1=C2C(=NC(=N1)N)N=CC(=N2)CN(C)C3=CC=C(C(N[C@...
# 2     742  115-02-6                 C([C@H](COC(=O)C=[N+]=[N-])N)(=O)O
# 3     750   55-98-1                     C[S](=O)(=O)OCCCCO[S](C)(=O)=O
# 4     752  154-42-7                         SC1=C2C(=NC(=N1)N)[NH]C=N2
#
#    abcc10    name
# 0   -0.23  NSC186
# 1    0.12  NSC740
# 2   -0.03  NSC742
# 3    0.04  NSC750
# 4    0.08  NSC752

# %%
THRESHOLD = -0.2
df_nci["label"] = df_nci["abcc10"].apply(lambda x: 1 if x <= THRESHOLD else 0)

# %%
df_all = pd.concat([df_previous, df_nci[["name", "smiles", "label"]]])
df_all.head()
# Out:
#           name                                             smiles  label
# 0   paclitaxel  CC1=C2C(C(=O)C3(C(CC4C(C3C(C(C2(C)C)(CC1OC(=O)...      1
# 1  vincristine  CCC1(CC2CC(C3=C(CCN(C2)C1)C4=CC=CC=C4N3)(C5=C(...      1
# 2         LTC4  CCCCCC=CCC=CC=CC=CC(C(CCCC(=O)O)O)SCC(C(=O)NCC...      1
# 3       E217bG  CC12CCC3C(C1CCC2OC4C(C(C(C(O4)C(=O)O)O)O)O)CCC...      1
# 4  gemcitabine              C1=CN(C(=O)N=C1N)C2C(C(C(O2)CO)O)(F)F      1

# %%
df_all.shape
# Out:
# (1529, 3)

# %%
df_all["std_smiles"] = df_all["smiles"].apply(standardize_smiles)
df_all.head()
# Out:
# RDKit ERROR: [08:45:01] Explicit valence for atom # 7 Sn, 5, is greater than permitted
# RDKit ERROR: [08:45:01] Explicit valence for atom # 28 N, 4, is greater than permitted
# RDKit ERROR: [08:45:01] Explicit valence for atom # 1 Sn, 5, is greater than permitted
# RDKit ERROR: [08:45:01] Explicit valence for atom # 25 B, 7, is greater than permitted
# RDKit ERROR: [08:45:01] Explicit valence for atom # 18 N, 4, is greater than permitted
# RDKit ERROR: [08:45:01] Explicit valence for atom # 31 N, 4, is greater than permitted
# RDKit ERROR: [08:45:01] Explicit valence for atom # 10 N, 4, is greater than permitted
# RDKit ERROR: [08:45:01] Explicit valence for atom # 32 N, 4, is greater than permitted
# RDKit ERROR: [08:45:01] Explicit valence for atom # 0 Pb, 5, is greater than permitted
# RDKit ERROR: [08:45:01] Explicit valence for atom # 0 Tl, 7, is greater than permitted
# RDKit ERROR: [08:45:01] Explicit valence for atom # 2 Ga, 9, is greater than permitted
# RDKit ERROR: [08:45:01] Explicit valence for atom # 49 B, 4, is greater than permitted
# RDKit ERROR: [08:45:02] Explicit valence for atom # 7 N, 4, is greater than permitted
# RDKit ERROR: [08:45:02] Explicit valence for atom # 31 N, 4, is greater than permitted
# RDKit ERROR: [08:45:02] Explicit valence for atom # 8 N, 4, is greater than permitted
# RDKit ERROR: [08:45:02] Explicit valence for atom # 8 N, 4, is greater than permitted
# RDKit ERROR: [08:45:02] Explicit valence for atom # 8 N, 4, is greater than permitted
# RDKit ERROR: [08:45:02] Explicit valence for atom # 8 N, 4, is greater than permitted
# RDKit ERROR: [08:45:02] Explicit valence for atom # 7 Sn, 6, is greater than permitted
# RDKit ERROR: [08:45:02] Explicit valence for atom # 1 Sn, 6, is greater than permitted
# RDKit ERROR: [08:45:02] Explicit valence for atom # 7 Sn, 6, is greater than permitted
# RDKit ERROR: [08:45:02] Explicit valence for atom # 43 N, 4, is greater than permitted
# RDKit ERROR: [08:45:02] Explicit valence for atom # 4 N, 4, is greater than permitted
#           name                                             smiles  label  \
# 0   paclitaxel  CC1=C2C(C(=O)C3(C(CC4C(C3C(C(C2(C)C)(CC1OC(=O)...      1
# 1  vincristine  CCC1(CC2CC(C3=C(CCN(C2)C1)C4=CC=CC=C4N3)(C5=C(...      1
# 2         LTC4  CCCCCC=CCC=CC=CC=CC(C(CCCC(=O)O)O)SCC(C(=O)NCC...      1
# 3       E217bG  CC12CCC3C(C1CCC2OC4C(C(C(C(O4)C(=O)O)O)O)O)CCC...      1
# 4  gemcitabine              C1=CN(C(=O)N=C1N)C2C(C(C(O2)CO)O)(F)F      1
#
#                                           std_smiles
# 0  CC(=O)OC1C(=O)C2(C)C(O)CC3OCC3(OC(C)=O)C2C(OC(...
# 1  CCC1(O)CC2CN(CCc3c([nH]c4ccccc34)C(C(=O)OC)(c3...
# 2  CCCCCC=CCC=CC=CC=CC(SCC(NC(=O)CCC(N)C(=O)O)C(=...
# 3  CC12CCC3c4ccc(O)cc4CCC3C1CCC2OC1OC(C(=O)O)C(O)...
# 4                  Nc1ccn(C2OC(CO)C(O)C2(F)F)c(=O)n1

# %%
# Count smiles cannot be standardized
len(df_all[df_all["std_smiles"]=="error"])
# Out:
# 23

# %%
df_all[df_all["std_smiles"]=="error"]
# Out:
#            name                                             smiles  label  \
# 477   NSC353527  [NH+](CC)(CC)CC.[Sn]([O+]=C([NH2+]C1=CC=C(OCC)...      0
# 643   NSC623527  CCCCCCCCCCCCCCCCCCOC[C@@H](COCCOCC[N]1(CCCC1)C...      0
# 654   NSC624659  [Br-][Sn]2([Br-])([C-]1=CC=CC=C1)[C-]4=C([NH+]...      0
# 745   NSC633558  [S@+]12CC[S@+]3CC[S@+]4CC[S@@+]5CC[S@+]6CC[S@@...      0
# 829   NSC639966   C(CCCCCCCCCO[P](=O)(O)OC1CC[N](CC1)(C)C)CCCCCCCC      0
# 885   NSC643826  O(C[C@@H](N(C)CCCCCCCCCCCCCCCCCC)CO[P](=O)(O)O...      0
# 886   NSC643827  N(C[C@@H](O[P](=O)(O)OCC[N](C)(C)C)COC)(CCCCCC...      0
# 887   NSC643828  [C@H](OC)(CN(CCCCCCCCCCCCCCCCCC)C)CO[P](=O)(O)...      0
# 899   NSC644908  [Pb]4([C-]1=CC=CC=C1)([C-]2=CC=CC=C2)([C-]3=CC...      0
# 900   NSC644916  [Tl+3]1([O+]=C([CH-]C(=[O+]1)C2=CC=CC=C2)C3=CC...      0
# 966   NSC647062  C2(=[S+][Ga+3]13([S+]=C(N(CC)CC)[SH+]1)([SH+]2...      0
# 1130  NSC676863  [C@@H]1(C(P=P[C@H]1[P+](C2=CC=CC=C2)(C3=CC=CC=...      0
# 1315  NSC694253  C1(=CC(=CC=C1Cl)[N](=O)O)C(=O)NC2=NC3=C(S2)C=C...      0
# 1316  NSC694255  C14=CC(=CC=C1C(=C(N(C2=NC3=C(S2)C=CC=C3)C4=O)N...      0
# 1317  NSC694259  C1=CC2=C(C=C1)[N]3C(=[N]2C)C(=C(C4=CC=CC=C34)N...      0
# 1318  NSC694262  C1=CC2=C(C=C1)[N]3C(=[N]2C)C(=C(C4=CC=CC=C34)N...      0
# 1319  NSC694263  C1=CC2=C(C=C1)[N]3C(=[N]2C)C(=C(C4=CC=CC=C34)N...      0
# 1320  NSC694268  C1=CC2=C(C=C1)[N]3C(=[N]2C)C(=C(C4=CC=CC=C34)N...      0
# 1333  NSC695416  [CH-](C1=CC=CC=C1)[Sn]3([Cl-])([Cl-])([CH-]C2=...      0
# 1334  NSC695417  [Cl-][Sn]([NH+]1C=CC2=CC=CC=C12)([NH+]3C=CC4=C...      0
# 1335  NSC695418  [CH-](C1=CC=CC=C1)[Sn]3([NH+]=C=S)([NH+]=C=S)(...      0
# 1387  NSC697471  [C@@H]5(O[C@@H]([C@@H]([C@H](OCC(=O)N1CCC[C@H]...      0
# 1404  NSC698276  C1=C(C=C[N](=C1)BC#N)C(=O)NNCC2=CC(=CC=C2)C(F)...      0
#
#      std_smiles
# 477       error
# 643       error
# 654       error
# 745       error
# 829       error
# 885       error
# 886       error
# 887       error
# 899       error
# 900       error
# 966       error
# 1130      error
# 1315      error
# 1316      error
# 1317      error
# 1318      error
# 1319      error
# 1320      error
# 1333      error
# 1334      error
# 1335      error
# 1387      error
# 1404      error

# %%
df_all = df_all[df_all["std_smiles"]!="error"]
df_all.shape
# Out:
# (1506, 4)

# %%
df_all = df_all.drop(["smiles"], axis=1)

# %%
df_all.head()
# Out:
#           name  label                                         std_smiles
# 0   paclitaxel      1  CC(=O)OC1C(=O)C2(C)C(O)CC3OCC3(OC(C)=O)C2C(OC(...
# 1  vincristine      1  CCC1(O)CC2CN(CCc3c([nH]c4ccccc34)C(C(=O)OC)(c3...
# 2         LTC4      1  CCCCCC=CCC=CC=CC=CC(SCC(NC(=O)CCC(N)C(=O)O)C(=...
# 3       E217bG      1  CC12CCC3c4ccc(O)cc4CCC3C1CCC2OC1OC(C(=O)O)C(O)...
# 4  gemcitabine      1                  Nc1ccn(C2OC(CO)C(O)C2(F)F)c(=O)n1

# %%
df_all.to_csv("../data/all_compounds_with_std_smiles.csv")
